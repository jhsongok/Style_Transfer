# %%
# 내 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Colab에서 GitHub 에 있는 데이터 가져오기
# model 다운로드 URL : https://github.com/anishathalye/neural-style
# Clone Web URL 를 복사해 옵니다.

# !git clone https://github.com/anishathalye/neural-style.git
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 346, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 346 (delta 13), reused 25 (delta 7), pack-reused 314
# Receiving objects: 100% (346/346), 2.65 MiB | 37.17 MiB/s, done.
# Resolving deltas: 100% (179/179), done.

# %%
# VGG19 모델을 내려받는다
# !wget https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# --2021-10-29 14:31:02--  https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  34.7MB/s    in 15s
#
# 2021-10-29 14:31:17 (34.5 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# 파일 이동
# !mv imagenet-vgg-verydeep-19.mat neural-style/
print('files move complete!!')
# Out:
# files move complete!!

# %%
# %cd neural-style
# !pip install -r requirements.txt
# Out:
# /content/neural-style
# ...

# %%
# !python neural_style.py --content <content file> --styles <style file> --output <output file>
# !python neural_style.py --content '/content/gdrive/MyDrive/Style_Transfer/rear_garden.png' --styles '/content/gdrive/MyDrive/Style_Transfer/image/RAIN-PRINCESS.jpg' --output '/content/output_rear_garden1.png'
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-10-29 14:38:04.124263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-29 14:38:04.132803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-29 14:38:04.133451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# --preserve-colors : content file color 를 반영하여 style 을 만듬 
# !python neural_style.py --content '/content/gdrive/MyDrive/Style_Transfer/rear_garden.png' --styles '/content/gdrive/MyDrive/Style_Transfer/image/RAIN-PRINCESS.jpg' --output '/content/output_rear_garden2.png' --preserve-colors
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-10-29 14:39:33.129085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-29 14:39:33.137279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-29 14:39:33.137860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
